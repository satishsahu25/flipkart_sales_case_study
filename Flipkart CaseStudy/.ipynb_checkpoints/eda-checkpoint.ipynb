# %%
import numpy as np
import pandas as pd

# %%
import plotly.express as px

# %%
df=pd.read_csv('flipkart.csv')
df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
df.tail()
# Out:
#        Brand      Model         Color Memory Storage  Rating  Selling Price  \
# 2642  Xiaomi  Redmi Y3       Bold Red   4 GB   64 GB     4.3        12999.0
# 2643  Xiaomi  Redmi Y3   Elegant Blue   3 GB   32 GB     4.3         9450.0
# 2644  Xiaomi  Redmi Y3   Elegant Blue   4 GB   64 GB     4.2        12999.0
# 2645  Xiaomi  Redmi Y3    Prime Black   3 GB   32 GB     4.2         9950.0
# 2646  Xiaomi  Redmi Y3    Prime Black   4 GB   64 GB     4.3        12499.0
#
#       Original Price
# 2642         13999.0
# 2643             NaN
# 2644             NaN
# 2645             NaN
# 2646         13999.0

# %%
df.dtypes
# Out:
# Brand              object
# Model              object
# Color              object
# Memory             object
# Storage            object
# Rating            float64
# Selling Price     float64
# Original Price    float64
# dtype: object

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2647.000000    2644.000000      969.000000
# mean      4.001700   26461.362330    29852.605779
# std       0.997499   29833.135164    27659.141051
# min       0.000000    1000.000000     1599.000000
# 25%       4.000000    9490.000000    12999.000000
# 50%       4.300000   14999.000000    18999.000000
# 75%       4.400000   29998.250000    34999.000000
# max       5.000000  179900.000000   189999.000000

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model                2
# Color              142
# Memory              42
# Storage             79
# Rating               0
# Selling Price        3
# Original Price    1678
# dtype: int64

# %%
# original price mein jyda null hai so lets drop it
newdf=df.drop(columns=['Original Price'])

# %%
newdf.isnull().sum()
# Out:
# Brand              0
# Model              2
# Color            142
# Memory            42
# Storage           79
# Rating             0
# Selling Price      3
# dtype: int64

# %%
newdf
# Out:
#        Brand      Model            Color Memory Storage  Rating  Selling Price
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5        11990.0
# ...      ...        ...              ...    ...     ...     ...            ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3        12999.0
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3         9450.0
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2        12999.0
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2         9950.0
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3        12499.0
#
# [2647 rows x 7 columns]

# %%
# lets drop the rows having null values
dfclean=newdf.dropna(axis=0)
dfclean
# Out:
#        Brand      Model            Color Memory Storage  Rating  Selling Price
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5        11990.0
# ...      ...        ...              ...    ...     ...     ...            ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3        12999.0
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3         9450.0
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2        12999.0
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2         9950.0
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3        12499.0
#
# [2436 rows x 7 columns]

# %%
dfclean.to_csv('cleanedata.csv',index=False)

# %%
dfclean.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0

# %%
# grouping brand wise
brands=dfclean.groupby(by='Brand').count().sort_values(ascending=False,by='Model')

# %%
brands.head()
# Out:
#          Model  Color  Memory  Storage  Rating  Selling Price
# Brand
# SAMSUNG    634    634     634      634     634            634
# Apple      346    346     346      346     346            346
# realme     245    245     245      245     245            245
# OPPO       243    243     243      243     243            243
# Xiaomi     164    164     164      164     164            164

# %%
# lets reset the index
brands=brands.reset_index()
brands.head()
# Out:
#      Brand  Model  Color  Memory  Storage  Rating  Selling Price
# 0  SAMSUNG    634    634     634      634     634            634
# 1    Apple    346    346     346      346     346            346
# 2   realme    245    245     245      245     245            245
# 3     OPPO    243    243     243      243     243            243
# 4   Xiaomi    164    164     164      164     164            164

# %% [markdown]
# # PLOTTING

# %%
fig=px.bar(brands,x='Model',y='Brand',color='Brand',title="Number of Models by brands")

# %%
fig.show()
# Out:
# <div>                            <div id="315cbae3-9d9c-40d6-9023-162667838eb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315cbae3-9d9c-40d6-9023-162667838eb8")) {                    Plotly.newPlot(                        "315cbae3-9d9c-40d6-9023-162667838eb8",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{y}<br>Model=%{x}<extra></extra>","legendgroup":"SAMSUNG","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SAMSUNG","offsetgroup":"SAMSUNG","orientation":"h","showlegend":true,"textposition":"auto","x":[634],"xaxis":"x","y":["SAMSUNG"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{y}<br>Model=%{x}<extra></extra>","legendgroup":"Apple","marker":{"color":"#EF553B","pattern":{"
# ...

# %%
df=dfclean

# %%
df['Color']=df['Color'].str.split(n=1).str[-1]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17796\1507767169.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Colors=df.groupby(by='Color').count().sort_values(ascending=False,by='Model')
Colors=Colors.reset_index()

# %%
Colors.head()
# Out:
#     Color  Brand  Model  Memory  Storage  Rating  Selling Price
# 0   Black    586    586     586      586     586            586
# 1    Blue    436    436     436      436     436            436
# 2   White    259    259     259      259     259            259
# 3    Gold    250    250     250      250     250            250
# 4  Silver    146    146     146      146     146            146

# %%
color_10=Colors.sort_values(ascending=False,by=['Model'])[:10]  #keval 10 hi plot karna hai
color_10
# Out:
#     Color  Brand  Model  Memory  Storage  Rating  Selling Price
# 0   Black    586    586     586      586     586            586
# 1    Blue    436    436     436      436     436            436
# 2   White    259    259     259      259     259            259
# 3    Gold    250    250     250      250     250            250
# 4  Silver    146    146     146      146     146            146
# 5     Red    123    123     123      123     123            123
# 6    Grey    103    103     103      103     103            103
# 7   Green     86     86      86       86      86             86
# 8  Purple     41     41      41       41      41             41
# 9    Gray     25     25      25       25      25             25

# %%
fig=px.bar(color_10,x='Color',color='Brand',y='Model',title='Top 10 in-Demand Colors')
fig.show()
# Out:
# <div>                            <div id="7c74a45b-a424-401c-9e9f-40d261b483fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c74a45b-a424-401c-9e9f-40d261b483fe")) {                    Plotly.newPlot(                        "7c74a45b-a424-401c-9e9f-40d261b483fe",                        [{"alignmentgroup":"True","hovertemplate":"Color=%{x}<br>Model=%{y}<br>Brand=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[586,436,259,250,146,123,103,86,41,25],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Black","Blue","White","Gold","Silver","Red","Grey","Green","Purple","Gray"],"xaxis":"x","y":[586,436,259,250,146,123,103,86,41,25],"yaxis":"y","t
# ...

# %%
ratings=df.groupby('Brand')[['Rating']].mean().sort_values(ascending=False,by='Rating').reset_index()

# %%
ratings.head()
# Out:
#           Brand    Rating
# 0  Google Pixel  4.514815
# 1          IQOO  4.400000
# 2          vivo  4.373077
# 3          POCO  4.310000
# 4          OPPO  4.207407

# %%
fig=px.bar(ratings,x='Rating',y='Brand',title='Average rating per brands',color='Brand')
fig.show()
# Out:
# <div>                            <div id="dc25742e-a1d7-4f20-a21e-a69f93e19a75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc25742e-a1d7-4f20-a21e-a69f93e19a75")) {                    Plotly.newPlot(                        "dc25742e-a1d7-4f20-a21e-a69f93e19a75",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{y}<br>Rating=%{x}<extra></extra>","legendgroup":"Google Pixel","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Google Pixel","offsetgroup":"Google Pixel","orientation":"h","showlegend":true,"textposition":"auto","x":[4.514814814814814],"xaxis":"x","y":["Google Pixel"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Brand=%{y}<br>Rating=%{x}<extra></extra>","legendgroup":"IQOO","mark
# ...

# %%
fig=px.box(df,x='Brand',y='Selling Price',title='Selling price per brand',color='Brand')
fig.show()
# Out:
# <div>                            <div id="a7dfae8c-9096-4bb0-ac68-a19c79886f23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7dfae8c-9096-4bb0-ac68-a19c79886f23")) {                    Plotly.newPlot(                        "a7dfae8c-9096-4bb0-ac68-a19c79886f23",                        [{"alignmentgroup":"True","hovertemplate":"Brand=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"OPPO","marker":{"color":"#636efa"},"name":"OPPO","notched":false,"offsetgroup":"OPPO","orientation":"v","showlegend":true,"x":["OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OPPO","OP
# ...

# %%
# Lets divide by segment of price
df['Segments']=pd.cut(df['Selling Price'],[0,25000,50000,np.inf],labels=['Low Budget','Mid-range','Expensive'])
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17796\2524104661.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brand Model  Color Memory Storage  Rating  Selling Price    Segments
# 0  OPPO   A53  Black   4 GB   64 GB     4.5        11990.0  Low Budget
# 1  OPPO   A53  Cream   4 GB   64 GB     4.5        11990.0  Low Budget
# 2  OPPO   A53  Black   6 GB  128 GB     4.3        13990.0  Low Budget
# 3  OPPO   A53  Cream   6 GB  128 GB     4.3        13990.0  Low Budget
# 4  OPPO   A53  Black   4 GB   64 GB     4.5        11990.0  Low Budget

# %%
segments=df.groupby(['Segments']).count().reset_index()
segments.head()
# Out:
#      Segments  Brand  Model  Color  Memory  Storage  Rating  Selling Price
# 0  Low Budget   1707   1707   1707    1707     1707    1707           1707
# 1   Mid-range    379    379    379     379      379     379            379
# 2   Expensive    350    350    350     350      350     350            350

# %%
fig=px.pie(segments,values='Model',names='Segments',title='Budget Division')
fig.show()
# Out:
# <div>                            <div id="872615d2-7dab-442f-b20c-2110eafc626e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("872615d2-7dab-442f-b20c-2110eafc626e")) {                    Plotly.newPlot(                        "872615d2-7dab-442f-b20c-2110eafc626e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segments=%{label}<br>Model=%{value}<extra></extra>","labels":["Low Budget","Mid-range","Expensive"],"legendgroup":"","name":"","showlegend":true,"values":[1707,379,350],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8
# ...

# %%
fig=px.scatter(df,x='Rating',y='Selling Price',color='Brand')
fig.show()
# Out:
# <div>                            <div id="92c606aa-5788-467c-b296-ce955466b552" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92c606aa-5788-467c-b296-ce955466b552")) {                    Plotly.newPlot(                        "92c606aa-5788-467c-b296-ce955466b552",                        [{"hovertemplate":"Brand=OPPO<br>Rating=%{x}<br>Selling Price=%{y}<extra></extra>","legendgroup":"OPPO","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"OPPO","showlegend":true,"x":[4.5,4.5,4.3,4.3,4.5,4.3,4.4,4.4,4.4,4.4,4.4,4.4,4.3,4.3,4.4,4.3,4.3,4.3,4.3,4.3,4.3,4.2,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,0.0,4.2,4.3,4.4,0.0,4.3,4.2,4.3,4.5,4.3,4.3,4.4,4.3,4.4,4.4,4.4,4.2,4.3,4.3,4.4,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3
# ...

# %%
fig=px.scatter(df,x='Rating',y='Segments',color='Brand')
fig.show()
# Out:
# <div>                            <div id="15b14ea0-d876-4650-afd3-502b8067fd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15b14ea0-d876-4650-afd3-502b8067fd2d")) {                    Plotly.newPlot(                        "15b14ea0-d876-4650-afd3-502b8067fd2d",                        [{"hovertemplate":"Brand=OPPO<br>Rating=%{x}<br>Segments=%{y}<extra></extra>","legendgroup":"OPPO","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"OPPO","showlegend":true,"x":[4.5,4.5,4.3,4.3,4.5,4.3,4.4,4.4,4.4,4.4,4.4,4.4,4.3,4.3,4.4,4.3,4.3,4.3,4.3,4.3,4.3,4.2,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,0.0,4.2,4.3,4.4,0.0,4.3,4.2,4.3,4.5,4.3,4.3,4.4,4.3,4.4,4.4,4.4,4.2,4.3,4.3,4.4,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.3,4.5,
# ...
